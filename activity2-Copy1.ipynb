# %% [markdown]
# # DOWNLOADING NECESSARY LIBRARIES

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC11\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC11\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC11\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC11\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %% [markdown]
# # IMPORTING DATASETS TO DATA FRAME

# %%
#variable_name / name

# %%
birds = pd.read_csv('datasets\\penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# # DESCRIPTIVE ANALYTICS

# %%
birds.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %% [markdown]
# # to flip the describe table t - transpose

# %%
birds.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %%
birds['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %% [markdown]
# # HOW TO DEFINE YOUR OWN COLUMN

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000 ,1)
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %% [markdown]
# # WHAT TO DO WITH NULL VALUES ?

# %%
birds['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds['weight'] = birds['weight'].fillna(birds['weight'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0           181.000000  3750.000000    male  2007     3.8
# 1           186.000000  3800.000000  female  2007     3.8
# ...

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000 ,2)
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0           181.000000  3750.000000    male  2007    3.75
# 1           186.000000  3800.000000  female  2007    3.80
# ...

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %% [markdown]
# # COLUM DATA TYPES

# %%
birds['year'] = birds['year'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    object
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
# dtypes: category(1), float64(5), int64(1), object(3)
# memory usage: 24.8+ KB

# %%
birds['species'] = birds['species'].astype('category')

# %%
birds['island'] = birds['island'].astype('category')

# %%
birds['sex'] = birds['sex'].astype('category')

# %%
birds['rowid'] = birds['rowid'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
birds['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %%
birds[birds['species'] == "Gentoo"].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# dtype: int64

# %%
birds[birds['species'] == "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# dtype: int64

# %% [markdown]
# #  1 HOW MANY GENTOO SPECIES HAVE WEIGHT MORE THAN 3KG??

# %%
birds['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['body_mass_g'] > 3000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 339    True
# 340    True
# 341    True
# 342    True
# 343    True
# Name: body_mass_g, Length: 344, dtype: bool

# %%
g = birds[
    birds['species'] == "Gentoo"]
g[g['weight'] > 5].count()
# Out:
# rowid                61
# species              61
# island               61
# bill_length_mm       61
# bill_depth_mm        61
# flipper_length_mm    61
# body_mass_g          61
# sex                  61
# year                 61
# weight               61
# dtype: int64

# %% [markdown]
# # 2 HOW MANY GENTOO SPECIES HAVE WEIGHT LESS THAN 3kg??

# %%
g = birds[
    birds['species'] == "Gentoo"]
g[g['weight'] < 5].count()
# Out:
# rowid                57
# species              57
# island               57
# bill_length_mm       57
# bill_depth_mm        57
# flipper_length_mm    57
# body_mass_g          57
# sex                  57
# year                 57
# weight               57
# dtype: int64

# %%
birds['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['island'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
birds[birds['island'] == 'Gentoo']
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
def getPenguin(penguin_name, island):
    return birds[(birds['species'] == penguin_name) &(birds['island'] == island)]

# %%
gentoo_dream = getPenguin("Gentoo", "Dream")
gentoo_dream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              0 non-null      category
#  1   species            0 non-null      category
#  2   island             0 non-null      category
#  3   bill_length_mm     0 non-null      float64
#  4   bill_depth_mm      0 non-null      float64
#  5   flipper_length_mm  0 non-null      float64
#  6   body_mass_g        0 non-null      float64
#  7   sex                0 non-null      category
#  8   year               0 non-null      category
#  9   weight             0 non-null      float64
# dtypes: category(5), float64(5)
# memory usage: 11.3 KB

# %%
gentoo_torg = getPenguin("Gentoo", "Torgersen")
gentoo_torg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              0 non-null      category
#  1   species            0 non-null      category
#  2   island             0 non-null      category
#  3   bill_length_mm     0 non-null      float64
#  4   bill_depth_mm      0 non-null      float64
#  5   flipper_length_mm  0 non-null      float64
#  6   body_mass_g        0 non-null      float64
#  7   sex                0 non-null      category
#  8   year               0 non-null      category
#  9   weight             0 non-null      float64
# dtypes: category(5), float64(5)
# memory usage: 11.3 KB

# %%
gentoo_Ade = getPenguin("Gentoo", "Adelie")
gentoo_Ade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              0 non-null      category
#  1   species            0 non-null      category
#  2   island             0 non-null      category
#  3   bill_length_mm     0 non-null      float64
#  4   bill_depth_mm      0 non-null      float64
#  5   flipper_length_mm  0 non-null      float64
#  6   body_mass_g        0 non-null      float64
#  7   sex                0 non-null      category
#  8   year               0 non-null      category
#  9   weight             0 non-null      float64
# dtypes: category(5), float64(5)
# memory usage: 11.3 KB

# %%
birds['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000, 1)
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0           181.000000  3750.000000    male  2007     3.8
# 1           186.000000  3800.000000  female  2007     3.8
# ...

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000, 2)
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0           181.000000  3750.000000    male  2007    3.75
# 1           186.000000  3800.000000  female  2007    3.80
# ...

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
birds['rowid'] = birds['rowid'].astype('category')
birds['year'] = birds['year'].astype('category')
birds['species'] = birds['species'].astype('category')
birds['island'] = birds['island'].astype('category')
birds['sex'] = birds['sex'].astype('category')

# %% [markdown]
# # filtering data based from columns

# %%
birds['body_mass_g']
# Out:
# 0      3750.000000
# 1      3800.000000
# 2      3250.000000
# 3      4201.754386
# 4      3450.000000
#           ...
# 339    4000.000000
# 340    3400.000000
# 341    3775.000000
# 342    4100.000000
# 343    3775.000000
# Name: body_mass_g, Length: 344, dtype: float64

# %%
birds['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3        male
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: category
# Categories (2, object): ['female', 'male']

# %% [markdown]
# # How to create your own column

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000,1)

# %%
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0           181.000000  3750.000000    male  2007     3.8
# 1           186.000000  3800.000000  female  2007     3.8
# ...

# %% [markdown]
# # Does any of the birds species live exclusively on an island

# %%
birds['wkilo'] = np.round(birds['body_mass_g'] / 1000, 1)

# %% [markdown]
# # Adelie in Biscoe

# %%
Adelie_Biscoe = birds[(birds['species'] == 'Adelie') &(birds['island'] == 'Biscoe')]

# %% [markdown]
# # Adelie in Dream

# %%
Adelie_Dream = birds[(birds['species'] == 'Adelie') &(birds['island'] == 'Dream')]

# %% [markdown]
# # Adelie in Torgersen

# %%
Adelie_Torgersen = birds[(birds['species'] == 'Adelie') &(birds['island'] == 'Torgersen')]

# %%
Adelie_Biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
Adelie_Dream
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %%
Adelie_Torgersen
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        39.10000       18.70000
# 1       2  Adelie  Torgersen        39.50000       17.40000
# 2       3  Adelie  Torgersen        40.30000       18.00000
# 3       4  Adelie  Torgersen        43.92193       17.15117
# 4       5  Adelie  Torgersen        36.70000       19.30000
# 5       6  Adelie  Torgersen        39.30000       20.60000
# 6       7  Adelie  Torgersen        38.90000       17.80000
# 7       8  Adelie  Torgersen        39.20000       19.60000
# 8       9  Adelie  Torgersen        34.10000       18.10000
# 9      10  Adelie  Torgersen        42.00000       20.20000
# 10     11  Adelie  Torgersen        37.80000       17.10000
# 11     12  Adelie  Torgersen        37.80000       17.30000
# 12     13  Adelie  Torgersen        41.10000       17.60000
# 13     14  Adelie  Torgersen        38.60000       21.20000
# 14     15  Adelie  Torgersen        34.60000       21.10000
# ...

# %%
Gentoo_Torgersen = birds[(birds['species'] == 'Gentoo') &(birds['island'] == 'Torgersen')]

# %%
Gentoo_Torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight, wkilo]
# Index: []

# %%
Gentoo_Adelie = birds[(birds['species'] == 'Gentoo') &(birds['island'] == 'Adelie')]

# %%
Gentoo_Adelie
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight, wkilo]
# Index: []

# %%
Gentoo_Biscoe = birds[(birds['species'] == 'Gentoo') &(birds['island'] == 'Biscoe')]

# %%
Gentoo_Biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year  weight  wkilo
# ...

# %%
total = adelie.count() = gentoo.count() = chains.count()
# Out:
#   Cell In[79], line 1
#     total = adelie.count() = gentoo.count() = chains.count()
#             ^
# SyntaxError: cannot assign to function call

# %% [markdown]
# # insight #1

# %% [markdown]
# # Gentoo penguins are live exclusively in the biscoe island

# %%
adelie_dream = getPenguin("Adelie", "Dream")
adelie_dream.info()

# %%
adelie_torg = getPenguin("Adelie", "Torgersen")
adelie_torg.info()

# %%
adelie_gen = getPenguin("Adelie", "Gentoo")
adelie_gen.info()

# %% [markdown]
# # insigth #2

# %% [markdown]
# # Adelie penguins are found in biscoe turgersen

# %%
adelie_gen = getPenguin("Adelie", "Gentoo")
adelie_gen.info()

# %% [markdown]
#  # insigth #3

# %% [markdown]
# # Chinstrap
#
# # Does the island impact the body mass of a birds species

# %%
A = np.round(birds[birds['species'] == "Adelie"]['wkilo'].mean(),1)

# %%
A

# %% [markdown]
# # insigth #4

# %% [markdown]
# # The island doesnt have an impact on the weight of the Adelie

# %%
Gentoo_Biscoe_w = np.round(Gentoo_Biscoe['wkilo'].mean(), 1)

# %%
Gentoo_Biscoe_w

# %%
Gentoo_Dream_w = np.round(Gentoo_Biscoe['wkilo'].mean(), 1)
Gentoo_Dream_w

# %%
Gentoo_Torgersen_w = np.round(Gentoo_Biscoe['wkilo'].mean(), 1)
Gentoo_Torgersen_w

# %% [markdown]
# # insigth #5

# %% [markdown]
# # The Average weight of Adelie Penguins is: 3.7

# %%
avg_chains = np.round(chains['weight'].mean(), 2)
avg_chains

# %% [markdown]
# # insigth #6

# %% [markdown]
# # Does island  doesnt have an impact on weight of the chinstrap

# %% [markdown]
# # insigth #7

# %% [markdown]
# # the haviest species among the three species in the dataset in the Gentoo penguin

# %%
birds_agg = birds.groupby(['species','island']).size()
birds_agg

# %% [markdown]
# # insigth #8

# %% [markdown]
# # The most  recorded male adelie penguinswas from year 2007 and 2010 on the dream island

# %%
penguins_agg4 = np.round(birds.groupby(['species','sex'])['wkilo'].mean())
penguins_agg4.unstack()

# %% [markdown]
# # insigth #9

# %% [markdown]
# # What is heavier adelie male or female

# %%
penguin_agg2 = np.round(birds.groupby(['species', 'island'])['wkilo'].mean(),1)
penguin_agg2

# %% [markdown]
# # insigth #10

# %% [markdown]
# # What year has the highest recorded male or female chinstrap both

# %% [markdown]
# # insigth #11
#
# # What year has the highest recorded male or female , Gentoo both

# %% [markdown]
# # Does the Bill  lenght effects the size of the depth?

# %%
b_depp_lenght_cor = birds['bill_length_mm'].corr(birds['bill_depth_mm'])

# %%
b_depp_lenght_cor

# %% [markdown]
# # insigth #12

# %% [markdown]
# # Bill Lenght has no Correlation with Bill depth

# %% [markdown]
# # Does bill length effects the size of the mass?

# %%
b1_depp_lenght_cor = birds['body_mass_g'].corr(birds['bill_length_mm'])

# %%
b1_depp_lenght_cor

# %% [markdown]
# # insigth #13

# %% [markdown]
# # The body mass has no effects on the bill length

# %% [markdown]
# # Does bill length Correlation the size of the flipper lenth?

# %%
b2_depp_lenght_cor = birds['flipper_length_mm'].corr(birds['bill_length_mm'])

# %%
b2_depp_lenght_cor

# %% [markdown]
# # insigth #14

# %% [markdown]
# # The biull length  has no effect on the flipper length

# %% [markdown]
# # Does body mass has Correlation on the flipper length?

# %%
b3_depp_lenght_cor = birds['body_mass_g'].corr(birds['flipper_length_mm'])

# %% [markdown]
# b3_depp_lenght_cor

# %% [markdown]
# # insigth # 15

# %% [markdown]
# # The body mass has no Correlation on the flipper length

# %%
pip install scipy

# %% [markdown]
# # Correlation between qualitative and quantitative

# %% [markdown]
# # Sex and Body mass

# %%
from scipy.stats import f_oneway

# %%
birds[birds['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
birds[birds['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
f_stats, p_value = f_oneway(birds[birds['sex'] == 'male']['body_mass_g'],
         birds[birds['sex'] == 'female']['body_mass_g'])
print(p_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 f_stats, p_value = f_oneway(birds[birds['sex'] == 'male']['body_mass_g'],
#       2          birds[birds['sex'] == 'female']['body_mass_g'])
#       3 print(p_value)
#
# NameError: name 'f_oneway' is not defined

# %% [markdown]
# # insigth #16
# # There is correlation  between sex and body mass

# %%
birds.info()
